# %%
from mylab.Cvideo import Video
import glob,os

# %%
dirpath=r"\\10.10.47.163\Data_archive\qiushou\miniscope_result\Results_206552"

# %%
videos = glob.glob(os.path.join(dirpath,"*30fps*/*.avi"))
videos
# Out:
# ['\\\\10.10.47.163\\Data_archive\\qiushou\\miniscope_result\\Results_206552\\20201112_232843_30fps_20200730\\msCam_concat.avi',
#  '\\\\10.10.47.163\\Data_archive\\qiushou\\miniscope_result\\Results_206552\\20201112_233105_30fps_20200731\\msCam_concat.avi',
#  '\\\\10.10.47.163\\Data_archive\\qiushou\\miniscope_result\\Results_206552\\20201112_233301_30fps_20200801\\msCam_concat.avi',
#  '\\\\10.10.47.163\\Data_archive\\qiushou\\miniscope_result\\Results_206552\\20201112_233436_30fps_20200804\\msCam_concat.avi',
#  '\\\\10.10.47.163\\Data_archive\\qiushou\\miniscope_result\\Results_206552\\20201112_233609_30fps_20200805\\msCam_concat.avi']

# %%
for video in videos:
    Video(video).transcode()
# Out:
# video haven't been tracked
# \\10.10.47.163\Data_archive\qiushou\miniscope_result\Results_206552\20201112_232843_30fps_20200730\msCam_concat.avi is as large as 6.29GB
# ffmpeg version N-93532-g772c73e61f Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 8.2.1 (GCC) 20190212
# ...
