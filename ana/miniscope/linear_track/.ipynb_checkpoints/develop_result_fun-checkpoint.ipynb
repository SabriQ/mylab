# %%
from mylab.process.miniscope.CminiLWresult import MiniLWResult
import pandas as pd
import numpy as np

# %%
lw_result = MiniLWResult(mouse_info_path=r"Z:\QiuShou\mouse_info\191173_info.txt"
    ,cnmf_result_dir = r"Z:\_Lab Data Analysis\02_Linear_Track\Miniscope_Linear_Track\Results_191173\20191110_160946_20191028-1102all"
    ,behave_dir= r"X:\miniscope\2019*\191173")
lw_result.run()
lw_result.save
lw_result.keys
# Out:
# loaded info: Z:\QiuShou\mouse_info\191173_info.txt
# loading cnmf_result...
# load post_processed_mat file
# loaded cnmf_result
# initialize Z:\_Lab Data Analysis\02_Linear_Track\Miniscope_Linear_Track\Results_191173\20191110_160946_20191028-1102all\ana_result.pkl
# X:\miniscope\2019*\191173
# save info: Z:\QiuShou\mouse_info\191173_info.txt
# ['context_orders', 'context_angles', 'ms_starts'] is okay
# ['behave_trackfiles', 'behave_timestamps', 'behave_logfiles', 'behave_videos'] is okay
# the line you draw are as long as 40 cm
# you have drawn rois of scale
# [448 281] [206 286]
# 0.16525398786891568 cm/pixel
# >>>>> [69537, 69537]
# frames of timestaps and traces are equal!
# (69537, 111)
# trace and ms_ts[ 0 8861 ]constructed as DataFrame
# trace and ms_ts[ 8861 20419 ]constructed as DataFrame
# trace and ms_ts[ 20419 26197 ]constructed as DataFrame
# trace and ms_ts[ 26197 32325 ]constructed as DataFrame
# trace and ms_ts[ 32325 38836 ]constructed as DataFrame
# ...

# %%
lw_result = MiniLWResult(mouse_info_path=r"Z:\QiuShou\mouse_info\191172_info.txt"
    ,cnmf_result_dir = r"Z:\_Lab Data Analysis\02_Linear_Track\Miniscope_Linear_Track\Results_191172\20191110_160835_20191028-1102all"
    ,behave_dir= r"X:\miniscope\2019*\191172")
lw_result.run()
lw_result.keys
lw_result.save
# Out:
# loaded info: Z:\QiuShou\mouse_info\191172_info.txt
# loading cnmf_result...
# load post_processed_mat file
# loaded cnmf_result
# initialize Z:\_Lab Data Analysis\02_Linear_Track\Miniscope_Linear_Track\Results_191172\20191110_160835_20191028-1102all\ana_result.pkl
# X:\miniscope\2019*\191172
# save info: Z:\QiuShou\mouse_info\191172_info.txt
# ['context_orders', 'context_angles', 'ms_starts'] is okay
# ['behave_trackfiles', 'behave_timestamps', 'behave_logfiles', 'behave_videos'] is okay
# the line you draw are as long as 40 cm
# you have drawn rois of scale
# [448 281] [206 286]
# 0.16525398786891568 cm/pixel
# >>>>> [79031, 79031]
# frames of timestaps and traces are equal!
# (79031, 664)
# trace and ms_ts[ 0 10408 ]constructed as DataFrame
# trace and ms_ts[ 10408 17735 ]constructed as DataFrame
# trace and ms_ts[ 17735 25844 ]constructed as DataFrame
# trace and ms_ts[ 25844 34719 ]constructed as DataFrame
# trace and ms_ts[ 34719 41286 ]constructed as DataFrame
# ...
